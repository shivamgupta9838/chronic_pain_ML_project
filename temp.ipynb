# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

input= pd.read_csv("pain_dataset_200P_4hz.csv")
input= input.iloc[93120:93600]

input
# Out:
#       person_ID   acc_x   acc_y   acc_z     eda    bvp    hr   temp  \
# 93120      P195  0.1800 -0.0052 -0.3531  1.3205  59.56  61.5  35.66
# 93121      P195  0.1113 -0.1353 -0.3611  1.3440  63.01  64.3  35.65
# 93122      P195  0.0976 -0.1591 -0.3982  1.3331  60.60  61.7  35.63
# 93123      P195  0.2173 -0.5873 -0.4082  1.4012  61.02  64.8  35.66
# 93124      P195  0.1988 -0.4486 -0.3700  1.3892  60.50  62.9  35.64
# ...         ...     ...     ...     ...     ...    ...   ...    ...
# 93595      P195  0.1318  0.3839  0.2869  1.0295  44.29  51.7  33.67
# 93596      P195  0.1216  0.5426  0.1433  0.9100  43.07  51.6  33.64
# 93597      P195 -0.0770  0.4481  0.3366  0.8083  42.35  52.4  33.70
# 93598      P195 -0.2709  0.3705  0.2592  0.8650  44.45  51.4  33.67
# 93599      P195 -0.1977  0.4883  0.3360  0.7573  45.85  50.3  33.65
#
#        pain_scale
# 93120           5
# 93121           5
# 93122           5
# 93123           5
# 93124           5
# ...           ...
# ...

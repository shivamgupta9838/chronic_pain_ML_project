# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

df = pd.read_csv(r"E:\program\chronic_pain\synthetic_physiopain_1to8_v2.csv")

# drop row 5 and 10
df = df.iloc[24320:]

df.to_csv("new_data.csv", index=False)

# %%
df.size
# Out:
# 1599984
